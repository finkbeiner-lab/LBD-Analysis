# %%
import pandas as pd
import numpy as np
import glob
import os

# %%
pwd
# Out:
# '/home/mahirwar/Projects/LBD/LBD-Analysis/src/data'

# %%
df = pd.read_csv("/home/mahirwar/Projects/LBD/LBD_Data/PDD_DLB 1989-2019_updated.csv",sep="\t")

# %%
df
# Out:
#     Autopsy no Gender Age/DOB Path Diagnosis  CG\n(aSyn)  EntCx\n(aSyn)  \
# 0      00/1027    NaN     NaN        DLB+AD          1.0            1.0
# 1      00/1108    NaN     NaN        DLB+AD          1.0            1.0
# 2      00/1140    NaN     NaN      pure DLB          1.0            1.0
# 3       01/104    NaN     NaN         DLB+AD         1.0            1.0
# 4       01/156    NaN     NaN        DLB+AD          1.0            1.0
# ..         ...    ...     ...            ...         ...            ...
# 202      PD537      M      84            PDD         1.0            1.0
# 203      PD538      M      73            PDD         1.0            1.0
# 204      PD544      M      81            PDD         1.0            1.0
# 205      PD553      M      77         PDD+AD         1.0            1.0
# 206      PD563      M      75            PDD         1.0            1.0
#
#      FCx \n(aSyn)  TCx \n(aSyn)  PCx \n(aSyn)
# 0             1.0           1.0           1.0
# ...

# %%
df.columns
# Out:
# Index(['Autopsy no', 'Gender', 'Age/DOB', 'Path Diagnosis', 'CG\n(aSyn)',
#        'EntCx\n(aSyn)', 'FCx \n(aSyn)', 'TCx \n(aSyn)', 'PCx \n(aSyn)'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# Autopsy no        00/1027
# Gender                NaN
# Age/DOB               NaN
# Path Diagnosis    DLB+AD
# CG\n(aSyn)            1.0
# EntCx\n(aSyn)         1.0
# FCx \n(aSyn)          1.0
# TCx \n(aSyn)          1.0
# PCx \n(aSyn)          1.0
# Name: 0, dtype: object

# %%
df["Path Diagnosis"].value_counts()
# Out:
# DLB+AD       66
# PDD          64
# pure DLB     22
# PDD+AD       19
# DLB+AD       18
# pure DLB     16
# PDD           1
# PD            1
# Name: Path Diagnosis, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# M    90
# F    50
# Name: Gender, dtype: int64

# %%
df['Autopsy no'].value_counts().sum()
# Out:
# 207

# %%
df.sum()
# Out:
# /tmp/ipykernel_594281/1703867807.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum()
# Autopsy no        00/102700/110800/114001/10401/15601/17202/0210...
# Path Diagnosis    DLB+AD DLB+AD pure DLB DLB+ADDLB+AD pure DLB D...
# CG\n(aSyn)                                                    168.0
# EntCx\n(aSyn)                                                 170.0
# FCx \n(aSyn)                                                  164.0
# TCx \n(aSyn)                                                  164.0
# PCx \n(aSyn)                                                  163.0
# dtype: object

# %%
dlb_wsi_dir = "/gladstone/finkbeiner/steve/work/data/npsad_data/monika/LBD_Dataset/LBD/DLB_cases"
pdd_wsi_dir = "/gladstone/finkbeiner/steve/work/data/npsad_data/monika/LBD_Dataset/LBD/PDD_cases/PDD_cases"

# %%
dlb_imagenames = sorted(glob.glob(os.path.join(dlb_wsi_dir, './*.svs')))
pdd_imagenames = sorted(glob.glob(os.path.join(pdd_wsi_dir, '././*.svs')))

# %%
dlb_imagenames_1 =[x.split("/")[-1] for x in dlb_imagenames]
pdd_imagenames_1 = [x.split("/")[-1] for x in pdd_imagenames]

# %%
len(dlb_imagenames)
# Out:
# 233

# %%
len(pdd_imagenames)
# Out:
# 288

# %%
len(dlb_imagenames_1)
# Out:
# 521

# %%
filelist_df = pd.DataFrame({"filename":dlb_imagenames_1})

# %%
filelist_df.to_csv("filename_recieved.csv")

# %%
len(dlb_imagenames)
# Out:
# 233

# %%
len(pdd_imagenames)
# Out:
# 288

# %%
dlb_imagenames[0]
# Out:
# '/gladstone/finkbeiner/steve/work/data/npsad_data/monika/LBD_Dataset/LBD/DLB_cases/./11_063_CG_aSyn_x200.svs'

# %%
pdd_imagenames[0]
# Out:
# '/gladstone/finkbeiner/steve/work/data/npsad_data/monika/LBD_Dataset/LBD/PDD_cases/PDD_cases/././PD001_Syn1_CG.svs'

# %%
patient_ids = []
for imgs in dlb_imagenames:
    name_split = imgs.split("/")[-1].split("_")
    patient_ids.append(name_split[0]+"/"+name_split[1])

for imgs in pdd_imagenames:
    name_split = imgs.split("/")[-1].split("_")
    patient_ids.append(name_split[0])

# %%
len(patient_ids)
# Out:
# 521

# %%
excel_patient_ids = df['Autopsy no'].values

# %%
not_present_list = [ids for ids in excel_patient_ids if ids not in patient_ids]

# %%
len(not_present_list)
# Out:
# 92

# %%
PD_patients_missing = [i for i in not_present_list if i.startswith("PD")]
PD_patients_missing, len(PD_patients_missing)
# Out:
# (['PD010',
#   'PD076',
#   'PD077',
#   'PD097',
#   'PD389',
#   'PD466',
#   'PD530',
#   'PD537',
#   'PD538',
#   'PD544',
#   'PD553',
#   'PD563'],
#  12)

# %%
dlb_wsi_dir = "/gladstone/finkbeiner/steve/work/data/npsad_data/monika/LBD_Dataset/LBD/DLB_cases/DLB_cases"
dlb_imagenames2 = sorted(glob.glob(os.path.join(dlb_wsi_dir, './*.svs')))

# %%
len(dlb_imagenames2)
# Out:
# 162

# %%
dlb_imagenames_1_1 =[x.split("/")[-1] for x in dlb_imagenames2]

# %%
dlb_imagenames_1_1
# Out:
# ['00_1027_Syn1_CG_200x.svs',
#  '00_1027_Syn1_EntCx_200x.svs',
#  '00_1027_Syn1_FCx_200x.svs',
#  '00_1027_Syn1_PCx_200x.svs',
#  '00_1027_Syn1_TCx_200x.svs',
#  '00_1094_Syn1_EntCx_200x.svs',
#  '00_1108_Syn1_CG_200x.svs',
#  '00_1108_Syn1_EntCx_200x.svs',
#  '00_1108_Syn1_FCx_200x.svs',
#  '00_1117_Syn1_EntCx_200x.svs',
#  '00_1140_Syn1_EntCx_200x.svs',
#  '01_104_Syn1_CG_200x.svs',
#  '01_104_Syn1_EntCx_200x.svs',
#  '01_104_Syn1_FCx_200x.svs',
#  '01_104_Syn1_PCx_200x.svs',
#  '01_104_Syn1_TCx_200x.svs',
#  '01_156_Syn1_CG_200x.svs',
#  '01_156_Syn1_EntCx_200x.svs',
#  '01_172_Syn1_EntCx_200x.svs',
#  '02_019_Syn1_CG_200x.svs',
#  '02_019_Syn1_EntCx_200x.svs',
#  '02_021_Syn1_CG_200x.svs',
#  '02_021_Syn1_EntCx_200x.svs',
#  '02_065_Syn1_CG_200x.svs',
#  '02_065_Syn1_EntCx_200x.svs',
#  '02_186_Syn1_CG_200x.svs',
#  '02_186_Syn1_EntCx_200x.svs',
#  '02_186_Syn1_FCx_200x.svs',
#  '02_186_Syn1_PCx_200x.svs',
#  '02_203_Syn1_CG_200x.svs',
#  '02_203_Syn1_EntCx_200x.svs',
# ...

# %%
filelist_df = pd.DataFrame({"filename":dlb_imagenames_1_1})
filelist_df.to_csv("filename_recieved2.csv")
